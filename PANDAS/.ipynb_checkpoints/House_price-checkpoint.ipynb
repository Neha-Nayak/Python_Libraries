# %%
import pandas as pd
df=pd.read_csv("houseprices.csv")
df
# Out:
#    OrganisationLabel                                    OrganisationURI  \
# 0       Lincolnshire  http://opendatacommunities.org/id/county-counc...
# 1       Lincolnshire  http://opendatacommunities.org/id/county-counc...
# 2       Lincolnshire  http://opendatacommunities.org/id/county-counc...
# 3       Lincolnshire  http://opendatacommunities.org/id/county-counc...
# 4       Lincolnshire  http://opendatacommunities.org/id/county-counc...
# ..               ...                                                ...
# 91      Lincolnshire  http://opendatacommunities.org/id/county-counc...
# 92      Lincolnshire  http://opendatacommunities.org/id/county-counc...
# 93      Lincolnshire  http://opendatacommunities.org/id/county-counc...
# 94      Lincolnshire  http://opendatacommunities.org/id/county-counc...
# 95      Lincolnshire  http://opendatacommunities.org/id/county-counc...
#
#           PublishedDate LatestData         DurationFrom           DurationTo  \
# ...

# %%
df1=df[["Month","GeoCode","GeoName","AveragePrice","AveragePriceDetached","AveragePriceSemiDetached","AveragePriceTerraced"]]
df1
# Out:
#       Month    GeoCode         GeoName  AveragePrice  AveragePriceDetached  \
# 0   2021-03  E10000019    Lincolnshire        207398                273965
# 1   2021-03  E07000136          Boston        174063                240313
# 2   2021-03  E07000137    East Lindsey        200819                249636
# 3   2021-03  E07000138         Lincoln        171574                277376
# 4   2021-03  E07000139  North Kesteven        232949                283618
# ..      ...        ...             ...           ...                   ...
# 91  2020-04  E07000138         Lincoln        156427                251369
# 92  2020-04  E07000139  North Kesteven        205193                248974
# 93  2020-04  E07000140   South Holland        188463                233784
# 94  2020-04  E07000141  South Kesteven        223172                313823
# 95  2020-04  E07000142    West Lindsey        171077                225452
#
#     AveragePriceSemiDetached  AveragePriceTerraced
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Month                     96 non-null     object
#  1   GeoCode                   96 non-null     object
#  2   GeoName                   96 non-null     object
#  3   AveragePrice              96 non-null     int64
#  4   AveragePriceDetached      96 non-null     int64
#  5   AveragePriceSemiDetached  96 non-null     int64
#  6   AveragePriceTerraced      96 non-null     int64
# dtypes: int64(4), object(3)
# memory usage: 5.4+ KB

# %%
import pandas as pd
df2=pd.read_csv("Bengaluru_House_Data.csv")
df2
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
df3=pd.read_csv("Bengaluru_House_Data.csv", nrows=40)
df3
# Out:
#                area_type   availability                  location       size  \
# 0   Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1             Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2         Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3   Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4   Super built-up  Area  Ready To Move                  Kothanur      2 BHK
# 5   Super built-up  Area  Ready To Move                Whitefield      2 BHK
# 6   Super built-up  Area         18-May          Old Airport Road      4 BHK
# 7   Super built-up  Area  Ready To Move              Rajaji Nagar      4 BHK
# 8   Super built-up  Area  Ready To Move              Marathahalli      3 BHK
# 9             Plot  Area  Ready To Move              Gandhi Bazar  6 Bedroom
# 10  Super built-up  Area         18-Feb                Whitefield      3 BHK
# ...

# %%
df4=df3.replace({
    'size':['4 Bedroom','6 Bedroom','3 Bedroom']
   },{'size':['4 BHK','6 BHK','3 BHK']})
df4
# Out:
#                area_type   availability                  location   size  \
# 0   Super built-up  Area         19-Dec  Electronic City Phase II  2 BHK
# 1             Plot  Area  Ready To Move          Chikka Tirupathi  4 BHK
# 2         Built-up  Area  Ready To Move               Uttarahalli  3 BHK
# 3   Super built-up  Area  Ready To Move        Lingadheeranahalli  3 BHK
# 4   Super built-up  Area  Ready To Move                  Kothanur  2 BHK
# 5   Super built-up  Area  Ready To Move                Whitefield  2 BHK
# 6   Super built-up  Area         18-May          Old Airport Road  4 BHK
# 7   Super built-up  Area  Ready To Move              Rajaji Nagar  4 BHK
# 8   Super built-up  Area  Ready To Move              Marathahalli  3 BHK
# 9             Plot  Area  Ready To Move              Gandhi Bazar  6 BHK
# 10  Super built-up  Area         18-Feb                Whitefield  3 BHK
# 11            Plot  Area  Ready To Move                Whitefield  4 BHK
# ...

# %%
g = df4.groupby(["availability","size","price"])
g

# %%
g.get_group(('Ready To Move','3 BHK',125))
# Out:
#                area_type   availability       location   size  society  \
# 34        Built-up  Area  Ready To Move  Kasturi Nagar  3 BHK  Kantsce
# 37  Super built-up  Area  Ready To Move   Kundalahalli  3 BHK  Dieldli
#
#    total_sqft  bath  balcony  price
# 34       1925     3      NaN  125.0
# 37       1724     3      2.0  125.0

# %%
df4.isnull().sum()
# Out:
# area_type        0
# availability     0
# location         0
# size             0
# society         14
# total_sqft       0
# bath             0
# balcony          4
# price            0
# dtype: int64

# %%
df5=df4.dropna()
df5
# Out:
#                area_type   availability                  location   size  \
# 0   Super built-up  Area         19-Dec  Electronic City Phase II  2 BHK
# 1             Plot  Area  Ready To Move          Chikka Tirupathi  4 BHK
# 3   Super built-up  Area  Ready To Move        Lingadheeranahalli  3 BHK
# 5   Super built-up  Area  Ready To Move                Whitefield  2 BHK
# 11            Plot  Area  Ready To Move                Whitefield  4 BHK
# 12  Super built-up  Area  Ready To Move        7th Phase JP Nagar  2 BHK
# 14            Plot  Area  Ready To Move                  Sarjapur  3 BHK
# 15  Super built-up  Area  Ready To Move               Mysore Road  2 BHK
# 16  Super built-up  Area  Ready To Move             Bisuvanahalli  3 BHK
# 17  Super built-up  Area  Ready To Move     Raja Rajeshwari Nagar  3 BHK
# 18  Super built-up  Area  Ready To Move     Ramakrishnappa Layout  3 BHK
# 21  Super built-up  Area         19-Dec                Binny Pete  3 BHK
# ...

# %%
df5.isnull().sum()
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# society         0
# total_sqft      0
# bath            0
# balcony         0
# price           0
# dtype: int64

# %%
df6=df4.fillna(value={
      'society':'not available',
    'balcony':'not available'
})
df6
# Out:
#                area_type   availability                  location   size  \
# 0   Super built-up  Area         19-Dec  Electronic City Phase II  2 BHK
# 1             Plot  Area  Ready To Move          Chikka Tirupathi  4 BHK
# 2         Built-up  Area  Ready To Move               Uttarahalli  3 BHK
# 3   Super built-up  Area  Ready To Move        Lingadheeranahalli  3 BHK
# 4   Super built-up  Area  Ready To Move                  Kothanur  2 BHK
# 5   Super built-up  Area  Ready To Move                Whitefield  2 BHK
# 6   Super built-up  Area         18-May          Old Airport Road  4 BHK
# 7   Super built-up  Area  Ready To Move              Rajaji Nagar  4 BHK
# 8   Super built-up  Area  Ready To Move              Marathahalli  3 BHK
# 9             Plot  Area  Ready To Move              Gandhi Bazar  6 BHK
# 10  Super built-up  Area         18-Feb                Whitefield  3 BHK
# 11            Plot  Area  Ready To Move                Whitefield  4 BHK
# ...

# %%
df6.isnull().sum()
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# society         0
# total_sqft      0
# bath            0
# balcony         0
# price           0
# dtype: int64

# %%
df3.describe()
# Out:
#             bath    balcony       price
# count  40.000000  36.000000   40.000000
# mean    2.750000   1.638889  112.198750
# std     1.149136   0.798312  120.469796
# min     1.000000   0.000000   15.000000
# 25%     2.000000   1.000000   45.375000
# 50%     2.500000   2.000000   61.000000
# 75%     3.000000   2.000000  123.500000
# max     6.000000   3.000000  600.000000
